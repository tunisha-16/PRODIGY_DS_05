# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load the dataset
accident_data = pd.read_csv('C:/Users/KarangulaTunisha/Downloads/API_SP.POP.TOTL_DS2_en_csv_v2_45183 (1)/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_45183.csv')

# Step 2: Data Preprocessing
# This step might involve handling missing values, converting data types, and filtering out irrelevant columns

# Step 3: Exploratory Data Analysis (EDA)
# Let's explore the dataset to understand its structure and distributions
print(accident_data.head())  # Display the first few rows of the dataset
print(accident_data.info())  # Display information about the dataset
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN
# ...

# %%
print(accident_data.columns)
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')

# %%
# Assuming 'road_condition' is the correct column name
#sns.countplot(x='road_condition', data=accident_data)
print(accident_data.columns)  # Print column names
print(accident_data.head())   # Print first few rows of the DataFrame
print(accident_data.info())   # Print information about the DataFrame
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Load the dataset (Sample data)
accident_data = pd.DataFrame({
    'weather_condition': ['Clear', 'Rain', 'Snow', 'Clear', 'Rain', 'Clear', 'Rain', 'Snow', 'Clear', 'Clear'],
    'latitude': [40.7128, 34.0522, 41.8781, 37.7749, 34.0522, 40.7128, 37.7749, 41.8781, 40.7128, 34.0522],
    'longitude': [-74.0060, -118.2437, -87.6298, -122.4194, -118.2437, -74.0060, -122.4194, -87.6298, -74.0060, -118.2437],
    'severity': ['Low', 'High', 'Medium', 'Low', 'High', 'Low', 'High', 'Medium', 'Low', 'High']
})

# Step 2: Data Preprocessing (Not shown for this example)

# Step 3: Exploratory Data Analysis (EDA)
# Visualize the distribution of accidents by weather condition
plt.figure(figsize=(10, 6))
sns.countplot(x='weather_condition', data=accident_data, palette='coolwarm')
plt.title('Distribution of Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# Step 4: Analyze patterns related to road conditions, weather, and time of day
# Visualize accident hotspots on a map (using latitude and longitude data)
plt.figure(figsize=(12, 8))
sns.scatterplot(x='longitude', y='latitude', data=accident_data, hue='severity', palette='viridis', alpha=0.7)
plt.title('Accident Hotspots')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Severity')
plt.show()

# %%
# Step 5: Further analysis and visualization
# Example: Analyze the relationship between weather condition and severity of accidents
plt.figure(figsize=(10, 6))
sns.countplot(x='weather_condition', hue='severity', data=accident_data, palette='Set2')
plt.title('Relationship between Weather Condition and Severity of Accidents')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.legend(title='Severity')
plt.xticks(rotation=45)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'longitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
